# %% [markdown]
# # Get model, install prereqs

# %%
#Installation

# Clone the ibm/tsfm
! git clone https://github.com/ibm-granite/granite-tsfm.git
! ls

# Change directory. Move inside the tsfm repo.
# %cd granite-tsfm
! ls

# Relax requirement for python version < 3.12
! sed -i.orig 's/3\.12/3.13/g' pyproject.toml

# Install the tsfm library
#! pip install ".[notebooks]"
#! python3 -m pip install ".[notebooks]"
! pip3 install ".[notebooks]"
# Out:
# Cloning into 'granite-tsfm'...
# remote: Enumerating objects: 1689, done.
# remote: Counting objects: 100% (530/530), done.
# remote: Compressing objects: 100% (265/265), done.
# remote: Total 1689 (delta 299), reused 339 (delta 265), pack-reused 1159
# Receiving objects: 100% (1689/1689), 18.35 MiB | 6.20 MiB/s, done.
# Resolving deltas: 100% (959/959), done.
# README.md                       install_tsfm.ipynb
# datasets                        ttm_finetuned_models
# granite-tsfm                    ttm_venice_levels.ipynb
# images                          ttm_venice_levels_watsonx.ipynb
# /Users/mrinalduzzi/Desktop/Projects/TTM/granite-tsfm
# /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# LICENSE        README.md      pyproject.toml tests          tsfmhfdemos
# Makefile       notebooks      scripts        tsfm_public    wiki.md
# Processing /Users/mrinalduzzi/Desktop/Projects/TTM/granite-tsfm
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pandas>=2.2.0 (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting scikit-learn (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached scikit_learn-1.5.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting transformers>=4.36.1 (from transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading transformers-4.42.3-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.5 MB/s eta 0:00:00
# Collecting datasets (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Collecting deprecated (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting urllib3<2,>=1.26.19 (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading urllib3-1.26.19-py2.py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 5.4 MB/s eta 0:00:00
# Collecting numpy<2 (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
# Collecting jupyter (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl.metadata (995 bytes)
# Collecting matplotlib (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading matplotlib-3.9.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting ipywidgets (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting plotly (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting kaleido (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting tensorboard (from tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from pandas>=2.2.0->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=2.2.0->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.2.0->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting filelock (from transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (24.1)
# Collecting pyyaml>=5.1 (from transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached regex-2024.5.15-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting requests (from transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting safetensors>=0.4.1 (from transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached safetensors-0.4.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached tokenizers-0.19.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting tqdm>=4.27 (from transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting accelerate>=0.21.0 (from transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading accelerate-0.31.0-py3-none-any.whl.metadata (19 kB)
# Collecting torch (from transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading torch-2.3.1-cp310-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Collecting pyarrow>=15.0.0 (from datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached pyarrow-16.1.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached xxhash-3.4.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached aiohttp-3.9.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting wrapt<2,>=1.10 (from deprecated->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: comm>=0.1.3 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (5.14.3)
# Collecting widgetsnbextension~=4.0.11 (from ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading widgetsnbextension-4.0.11-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.11 (from ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl.metadata (4.1 kB)
# Collecting notebook (from jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading notebook-7.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting qtconsole (from jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading qtconsole-5.5.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (6.29.4)
# Collecting contourpy>=1.0.1 (from matplotlib->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading fonttools-4.53.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 6.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached pillow-10.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tenacity>=6.2.0 (from plotly->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading tenacity-8.4.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting scipy>=1.6.0 (from scikit-learn->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading scipy-1.14.0-cp310-cp310-macosx_14_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.0 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting absl-py>=0.4 (from tensorboard->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading grpcio-1.64.1-cp310-cp310-macosx_12_0_universal2.whl.metadata (3.3 kB)
# Collecting markdown>=2.6.8 (from tensorboard->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.24.0,<5.0.0,>=3.19.6 (from tensorboard->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from tensorboard->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (65.5.0)
# Requirement already satisfied: six>1.9 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from tensorboard->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: psutil in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from accelerate>=0.21.0->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (6.0.0)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached frozenlist-1.4.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached multidict-6.0.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached yarl-1.9.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->datasets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (4.12.2)
# Requirement already satisfied: decorator in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (2.18.0)
# Requirement already satisfied: stack-data in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (0.6.3)
# Requirement already satisfied: exceptiongroup in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (1.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (4.9.0)
# Collecting charset-normalizer<4,>=2 (from requests->transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting certifi>=2017.4.17 (from requests->transformers>=4.36.1->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting sympy (from torch->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading sympy-1.12.1-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached MarkupSafe-2.1.5-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Requirement already satisfied: appnope in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (1.8.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (5.7.2)
# Requirement already satisfied: nest-asyncio in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (6.4.1)
# Collecting beautifulsoup4 (from nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading tinycss2-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading jupyter_server-2.14.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading jupyterlab_server-2.27.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.3,>=4.2.0 (from notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading jupyterlab-4.2.3-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Collecting webencodings (from bleach!=5.0.0->nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (4.2.2)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting tomli>=1.2.2 (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading Babel-2.15.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached json5-0.9.25-py3-none-any.whl.metadata (30 kB)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (0.2.13)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/mrinalduzzi/Desktop/Projects/TTM/.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.4.dev0+gf4c811e.d20240701) (0.2.2)
# Collecting mpmath<1.4.0,>=1.1.0 (from sympy->torch->transformers[torch]>=4.36.1->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting sniffio>=1.1 (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached rpds_py-0.18.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Downloading webcolors-24.6.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached cffi-1.16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.4.dev0+gf4c811e.d20240701)
#   Using cached types_python_dateutil-2.9.0.20240316-py3-none-any.whl.metadata (1.8 kB)
# Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# Using cached pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
# Downloading transformers-4.42.3-py3-none-any.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 57.2 MB/s eta 0:00:0000:0100:01
# Downloading urllib3-1.26.19-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 15.5 MB/s eta 0:00:00
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 48.1 MB/s eta 0:00:00
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading ipywidgets-8.1.3-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 14.1 MB/s eta 0:00:00
# Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Using cached kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl (85.8 MB)
# Downloading matplotlib-3.9.0-cp310-cp310-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 77.5 MB/s eta 0:00:00a 0:00:01
# Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 75.7 MB/s eta 0:00:00a 0:00:01
# Using cached scikit_learn-1.5.0-cp310-cp310-macosx_12_0_arm64.whl (11.0 MB)
# Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 83.6 MB/s eta 0:00:00ta 0:00:01
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 43.2 MB/s eta 0:00:00
# Using cached contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl (244 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fonttools-4.53.0-cp310-cp310-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 67.0 MB/s eta 0:00:00
# Using cached fsspec-2024.5.0-py3-none-any.whl (316 kB)
# Using cached aiohttp-3.9.5-cp310-cp310-macosx_11_0_arm64.whl (389 kB)
# Downloading grpcio-1.64.1-cp310-cp310-macosx_12_0_universal2.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 74.3 MB/s eta 0:00:00 0:00:01
# Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 40.9 MB/s eta 0:00:00
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 29.9 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl (66 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached pillow-10.3.0-cp310-cp310-macosx_11_0_arm64.whl (3.4 MB)
# Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Using cached pyarrow-16.1.0-cp310-cp310-macosx_11_0_arm64.whl (26.0 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl (169 kB)
# Using cached regex-2024.5.15-cp310-cp310-macosx_11_0_arm64.whl (278 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.7 MB/s eta 0:00:00
# Using cached safetensors-0.4.3-cp310-cp310-macosx_11_0_arm64.whl (410 kB)
# Downloading scipy-1.14.0-cp310-cp310-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 78.1 MB/s eta 0:00:0000:0100:01
# Downloading tenacity-8.4.2-py3-none-any.whl (28 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tokenizers-0.19.1-cp310-cp310-macosx_11_0_arm64.whl (2.4 MB)
# Downloading torch-2.3.1-cp310-none-macosx_11_0_arm64.whl (61.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 MB 66.5 MB/s eta 0:00:0000:0100:01
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 25.1 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 65.8 MB/s eta 0:00:00
# Using cached wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Downloading nbconvert-7.16.4-py3-none-any.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 21.3 MB/s eta 0:00:00
# Downloading notebook-7.2.1-py3-none-any.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 66.4 MB/s eta 0:00:0000:0100:01
# Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading qtconsole-5.5.2-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 14.2 MB/s eta 0:00:00
# Using cached xxhash-3.4.1-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached bleach-6.1.0-py3-none-any.whl (162 kB)
# Downloading certifi-2024.6.2-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.4/164.4 kB 19.9 MB/s eta 0:00:00
# Using cached charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl (120 kB)
# Using cached frozenlist-1.4.1-cp310-cp310-macosx_11_0_arm64.whl (52 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading jupyter_server-2.14.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 36.3 MB/s eta 0:00:00
# Downloading jupyterlab-4.2.3-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 82.9 MB/s eta 0:00:00 0:00:01
# Downloading jupyterlab_server-2.27.2-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 8.7 MB/s eta 0:00:00
# Using cached MarkupSafe-2.1.5-cp310-cp310-macosx_10_9_universal2.whl (18 kB)
# Using cached mistune-3.0.2-py3-none-any.whl (47 kB)
# Using cached multidict-6.0.5-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Using cached QtPy-2.4.1-py3-none-any.whl (93 kB)
# Using cached yarl-1.9.4-cp310-cp310-macosx_11_0_arm64.whl (79 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Downloading sympy-1.12.1-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 81.8 MB/s eta 0:00:00ta 0:00:01
# Downloading tinycss2-1.3.0-py3-none-any.whl (22 kB)
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.7 MB/s eta 0:00:00
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading Babel-2.15.0-py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 78.0 MB/s eta 0:00:0000:0100:01m
# Downloading fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached json5-0.9.25-py3-none-any.whl (30 kB)
# Using cached jsonschema-4.22.0-py3-none-any.whl (88 kB)
# Using cached jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached prometheus_client-0.20.0-py3-none-any.whl (54 kB)
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached rpds_py-0.18.1-cp310-cp310-macosx_11_0_arm64.whl (322 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached cffi-1.16.0-cp310-cp310-macosx_11_0_arm64.whl (176 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading webcolors-24.6.0-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Building wheels for collected packages: tsfm_public
#   Building wheel for tsfm_public (pyproject.toml) ... done
#   Created wheel for tsfm_public: filename=tsfm_public-0.2.4.dev0+gf4c811e.d20240701-py3-none-any.whl size=2304938 sha256=d1b3ac286d39ee9270aecf40acc1afbad42ad7c55761a3b64ebcd6de95e1a3a1
#   Stored in directory: /Users/mrinalduzzi/Library/Caches/pip/wheels/64/f0/2f/727967c39a455ece1ec225c0362008c710e1f34cd889093f94
# Successfully built tsfm_public
# Installing collected packages: webencodings, pytz, mpmath, kaleido, fastjsonschema, xxhash, wrapt, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, tzdata, types-python-dateutil, tqdm, tomli, tinycss2, threadpoolctl, terminado, tensorboard-data-server, tenacity, sympy, soupsieve, sniffio, send2trash, safetensors, rpds-py, rfc3986-validator, rfc3339-validator, regex, qtpy, pyyaml, python-json-logger, pyparsing, pycparser, pyarrow-hotfix, protobuf, prometheus-client, pillow, pandocfilters, overrides, numpy, networkx, multidict, mistune, MarkupSafe, markdown, kiwisolver, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, joblib, idna, h11, grpcio, fsspec, frozenlist, fqdn, fonttools, filelock, dill, defusedxml, cycler, charset-normalizer, certifi, bleach, babel, attrs, async-timeout, async-lru, absl-py, yarl, werkzeug, scipy, requests, referencing, pyarrow, plotly, pandas, multiprocess, jupyter-server-terminals, jinja2, httpcore, deprecated, contourpy, cffi, beautifulsoup4, arrow, anyio, aiosignal, torch, tensorboard, scikit-learn, matplotlib, jsonschema-specifications, isoduration, huggingface-hub, httpx, argon2-cffi-bindings, aiohttp, tokenizers, jsonschema, ipywidgets, argon2-cffi, accelerate, transformers, qtconsole, nbformat, jupyter-console, datasets, nbclient, jupyter-events, tsfm_public, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 accelerate-0.31.0 aiohttp-3.9.5 aiosignal-1.3.1 anyio-4.4.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 async-timeout-4.0.3 attrs-23.2.0 babel-2.15.0 beautifulsoup4-4.12.3 bleach-6.1.0 certifi-2024.6.2 cffi-1.16.0 charset-normalizer-3.3.2 contourpy-1.2.1 cycler-0.12.1 datasets-2.20.0 defusedxml-0.7.1 deprecated-1.2.14 dill-0.3.8 fastjsonschema-2.20.0 filelock-3.15.4 fonttools-4.53.0 fqdn-1.5.1 frozenlist-1.4.1 fsspec-2024.5.0 grpcio-1.64.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 huggingface-hub-0.23.4 idna-3.7 ipywidgets-8.1.3 isoduration-20.11.0 jinja2-3.1.4 joblib-1.4.2 json5-0.9.25 jsonpointer-3.0.0 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.1 jupyter-server-terminals-0.5.3 jupyterlab-4.2.3 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.2 jupyterlab-widgets-3.0.11 kaleido-0.2.1 kiwisolver-1.4.5 markdown-3.6 matplotlib-3.9.0 mistune-3.0.2 mpmath-1.3.0 multidict-6.0.5 multiprocess-0.70.16 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 networkx-3.3 notebook-7.2.1 notebook-shim-0.2.4 numpy-1.26.4 overrides-7.7.0 pandas-2.2.2 pandocfilters-1.5.1 pillow-10.3.0 plotly-5.22.0 prometheus-client-0.20.0 protobuf-4.25.3 pyarrow-16.1.0 pyarrow-hotfix-0.6 pycparser-2.22 pyparsing-3.1.2 python-json-logger-2.0.7 pytz-2024.1 pyyaml-6.0.1 qtconsole-5.5.2 qtpy-2.4.1 referencing-0.35.1 regex-2024.5.15 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.18.1 safetensors-0.4.3 scikit-learn-1.5.0 scipy-1.14.0 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.5 sympy-1.12.1 tenacity-8.4.2 tensorboard-2.17.0 tensorboard-data-server-0.7.2 terminado-0.18.1 threadpoolctl-3.5.0 tinycss2-1.3.0 tokenizers-0.19.1 tomli-2.0.1 torch-2.3.1 tqdm-4.66.4 transformers-4.42.3 tsfm_public-0.2.4.dev0+gf4c811e.d20240701 types-python-dateutil-2.9.0.20240316 tzdata-2024.1 uri-template-1.3.0 urllib3-1.26.19 webcolors-24.6.0 webencodings-0.5.1 websocket-client-1.8.0 werkzeug-3.0.3 widgetsnbextension-4.0.11 wrapt-1.16.0 xxhash-3.4.1 yarl-1.9.4
