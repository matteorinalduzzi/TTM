# %% [markdown]
# # Getting started with TinyTimeMixer (TTM) with Exogenous Infusion
#
# This notebooke demonstrates the usage of a pre-trained `TinyTimeMixer` model for several multivariate time series forecasting tasks with exogenous infusion. For details related to model architecture, refer to the [TTM paper](https://arxiv.org/pdf/2401.03955.pdf).
#
# In this example, we will use a pre-trained TTM-512-96 model. That means the TTM model can take an input of 512 time points (`context_length`), and can forecast upto 96 time points (`forecast_length`) in the future. We will use the pre-trained TTM in two settings:
# 1. **Zero-shot**: The pre-trained TTM will be directly used to evaluate on the `test` split of the target data. Note that the TTM was NOT pre-trained on the target data.
# 2. **Fine-tune*: The pre-trained TTM will be quickly fine-tuned onthe `train` split of the target data, and subsequently, evaluated on the `test` part of the target data. During finetuing, we used the future values mentioned in `control_columns` as exogenous features for modelling. Search for `# exog:` keyword for important parameters to edit for exogenous infusion.
#
# Note: Alternatively, this notebook can be modified to try the TTM-1024-96 model.
#
# Pre-trained TTM models will be fetched from the [Hugging Face TTM Model Repository](https://huggingface.co/ibm-granite/granite-timeseries-ttm-v1).

# %% [markdown]
# ## Installation

# %%
# Install the tsfm library
! git clone https://github.com/ibm-granite/granite-tsfm.git
# !ls

# Change directory. Move inside the tsfm repo.
# %cd granite-tsfm
! ls

# Install the tsfm library
! pip install ".[notebooks]"
# Out:
# fatal: destination path 'granite-tsfm' already exists and is not an empty directory.
# README.md	    ttm_finetuned_models
# datasets	    ttm_venice_levels.ipynb
# granite-tsfm	    ttm_venice_levels_watsonx.ipynb
# images		    ttm_with_exog_tutorial.ipynb
# install_tsfm.ipynb  ttm_with_exog_tutorial.ipynb:Zone.Identifier
# /home/proz/Progetti/ttm_new/TTM/granite-tsfm
# LICENSE    UNKNOWN.egg-info  pyproject.toml	  services     tsfmhfdemos
# Makefile   build	     pyproject.toml.orig  tests        wiki.md
# README.md  notebooks	     scripts		  tsfm_public
# /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Processing /home/proz/Progetti/ttm_new/TTM/granite-tsfm
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pandas>=2.2.0 (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 496.4 kB/s eta 0:00:00a 0:00:01
# Collecting scikit-learn (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting transformers>=4.38.0 (from transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading transformers-4.47.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 862.9 kB/s eta 0:00:00a 0:00:01
# Collecting datasets (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting deprecated (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting urllib3<2,>=1.26.19 (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 1.6 MB/s eta 0:00:00
# Collecting numpy<2 (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# Collecting jupyter (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting matplotlib (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading matplotlib-3.9.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting ipywidgets (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting plotly (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting kaleido (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Collecting tensorboard (from tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from pandas>=2.2.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=2.2.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.2.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting filelock (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.24.0 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading huggingface_hub-0.26.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20.0 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (24.2)
# Collecting pyyaml>=5.1 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 281.2 kB/s eta 0:00:00a 0:00:01
# Collecting requests (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading safetensors-0.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tqdm>=4.27 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 368.8 kB/s eta 0:00:00a 0:00:01
# Collecting torch (from transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting accelerate>=0.26.0 (from transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading accelerate-1.2.0-py3-none-any.whl.metadata (19 kB)
# Collecting pyarrow>=15.0.0 (from datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading pyarrow-18.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading aiohttp-3.11.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting wrapt<2,>=1.10 (from deprecated->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading wrapt-1.17.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting notebook (from jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading notebook-7.3.1-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (6.29.5)
# Collecting jupyterlab (from jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyterlab-4.3.2-py3-none-any.whl.metadata (16 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading fonttools-4.55.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 337.6 kB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting tenacity>=6.2.0 (from plotly->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting scipy>=1.6.0 (from scikit-learn->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 130.7 kB/s eta 0:00:00a 0:00:01
# Collecting joblib>=1.2.0 (from scikit-learn->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting absl-py>=0.4 (from tensorboard->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading grpcio-1.68.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting markdown>=2.6.8 (from tensorboard->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting setuptools>=41.0.0 (from tensorboard->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Using cached setuptools-75.6.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: six>1.9 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from tensorboard->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (1.17.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: psutil in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from accelerate>=0.26.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (6.1.0)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 157.9 kB/s eta 0:00:00a 0:00:01
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub<1.0,>=0.24.0->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: decorator in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (2.18.0)
# Requirement already satisfied: stack_data in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (0.6.3)
# Collecting charset-normalizer<4,>=2 (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading charset_normalizer-3.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting networkx (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch->transformers[torch]>=4.38.0->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (1.8.9)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (5.7.2)
# Requirement already satisfied: nest-asyncio in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (6.4.2)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx~=0.28.0 (from jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting beautifulsoup4 (from nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nbclient-0.10.1-py3-none-any.whl.metadata (8.2 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting webencodings (from bleach!=5.0.0->nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting anyio (from httpx~=0.28.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading anyio-4.7.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting httpcore==1.* (from httpx~=0.28.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx~=0.28.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (4.3.6)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (0.7.0)
# Requirement already satisfied: wcwidth in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (0.2.13)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: executing>=1.2.0 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (3.0.0)
# Requirement already satisfied: pure-eval in /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.18.dev9+g98730fd.d20241209) (0.2.3)
# Collecting sniffio>=1.1 (from anyio->httpx~=0.28.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading rpds_py-0.22.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading cffi-1.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public==0.2.18.dev9+g98730fd.d20241209)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 727.6 kB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 574.0 kB/s eta 0:00:0000:0100:01
# Downloading transformers-4.47.0-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 748.1 kB/s eta 0:00:0000:010:01
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 349.2 kB/s eta 0:00:00a 0:00:01
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 625.0 kB/s eta 0:00:00a 0:00:01
# Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.0 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib-3.9.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 10.9 MB/s eta 0:00:0000:0100:01
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 14.7 MB/s eta 0:00:0000:0100:01
# Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 9.1 MB/s eta 0:00:0000:0100:01
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 14.8 MB/s eta 0:00:00a 0:00:01
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Downloading accelerate-1.2.0-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.3/336.3 kB 14.6 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 9.2 MB/s eta 0:00:00ta 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading fonttools-4.55.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 11.5 MB/s eta 0:00:00a 0:00:01
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading aiohttp-3.11.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.4 MB/s eta 0:00:00a 0:00:01
# Downloading grpcio-1.68.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 11.8 MB/s eta 0:00:0000:0100:01
# Downloading huggingface_hub-0.26.5-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.8/447.8 kB 10.6 MB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 7.6 MB/s eta 0:00:00ta 0:00:01
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 5.3 MB/s eta 0:00:00ta 0:00:01
# Downloading kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.4 MB/s eta 0:00:00a 0:00:01
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 4.7 MB/s eta 0:00:00 0:00:01
# Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 10.1 MB/s eta 0:00:00 0:00:01m
# Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 5.8 MB/s eta 0:00:00ta 0:00:01
# Downloading pyarrow-18.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (40.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 MB 10.9 MB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 50.8 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 10.9 MB/s eta 0:00:0000:0100:01
# Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 14.8 MB/s eta 0:00:00a 0:00:01
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 1.6 MB/s eta 0:00:00ta 0:00:01
# Downloading safetensors-0.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (434 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.8/434.8 kB 9.0 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 8.4 MB/s eta 0:00:0000:0100:01m
# Using cached setuptools-75.6.0-py3-none-any.whl (1.2 MB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 9.4 MB/s eta 0:00:00a 0:00:01m
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 7.9 MB/s eta 0:00:0000:0100:01
# Downloading torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 5.8 MB/s eta 0:00:0000:01m0:04m
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 6.9 MB/s eta 0:00:0000:0100:02m
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 9.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 5.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 5.2 MB/s eta 0:00:0000:0100:03m
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 355.3 kB/s eta 0:00:0000:0100:13
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 7.7 MB/s eta 0:00:0000:0100:010m
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.9 MB/s eta 0:00:0000:01m00:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:0000:0100:01m
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 5.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 2.6 MB/s eta 0:00:00ta 0:00:01
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 6.2 MB/s eta 0:00:0000:0100:01m
# Downloading triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 7.0 MB/s eta 0:00:0000:0100:01
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.6 MB/s eta 0:00:00
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 8.0 MB/s eta 0:00:00a 0:00:01
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 4.5 MB/s eta 0:00:00a 0:00:01
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 9.1 MB/s eta 0:00:00a 0:00:01
# Downloading wrapt-1.17.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 20.0 MB/s eta 0:00:00
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading jupyterlab-4.3.2-py3-none-any.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 7.0 MB/s eta 0:00:0000:0100:01
# Downloading nbconvert-7.16.4-py3-none-any.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading notebook-7.3.1-py3-none-any.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 6.7 MB/s eta 0:00:0000:0100:01
# Downloading xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 4.7 MB/s eta 0:00:00a 0:00:01
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 5.0 MB/s eta 0:00:00
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 4.4 MB/s eta 0:00:00a 0:00:01
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 kB 5.5 MB/s eta 0:00:00ta 0:00:01
# Downloading charset_normalizer-3.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 907.8 kB/s eta 0:00:00 0:00:01
# Downloading frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.6 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 2.4 MB/s eta 0:00:00 0:00:01
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 4.0 MB/s eta 0:00:00
# Downloading jupyter_server-2.14.2-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 258.1 kB/s eta 0:00:000:00:01
# Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 3.1 MB/s eta 0:00:00 0:00:01
# Downloading nbclient-0.10.1-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 1.9 MB/s eta 0:00:00ta 0:00:01
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.6/243.6 kB 836.4 kB/s eta 0:00:00a 0:00:01
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.9/336.9 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 1.2 MB/s eta 0:00:00a 0:00:01m
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.4 MB/s eta 0:00:0000:0100:01
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading anyio-4.7.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading babel-2.16.0-py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 2.4 MB/s eta 0:00:0000:0100:01
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 4.2 MB/s eta 0:00:00
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.0 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rpds_py-0.22.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 795.7 kB/s eta 0:00:00a 0:00:01
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 662.9 kB/s eta 0:00:00--:--
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading cffi-1.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (479 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 479.4/479.4 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 2.9 MB/s eta 0:00:00ta 0:00:01
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Building wheels for collected packages: tsfm_public
#   Building wheel for tsfm_public (pyproject.toml) ... done
#   Created wheel for tsfm_public: filename=tsfm_public-0.2.18.dev9+g98730fd.d20241209-py3-none-any.whl size=2337294 sha256=1d7b0c8354a912a9f8b507d4990c4d99afc3fa34a41eb848edbd9f41634226e1
#   Stored in directory: /home/proz/.cache/pip/wheels/b6/92/3b/de932df39627bdec9b9b60aee01471f8172244a2884e290879
# Successfully built tsfm_public
# Installing collected packages: webencodings, pytz, mpmath, kaleido, fastjsonschema, xxhash, wrapt, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, tzdata, typing-extensions, types-python-dateutil, tqdm, tinycss2, threadpoolctl, terminado, tensorboard-data-server, tenacity, sympy, soupsieve, sniffio, setuptools, send2trash, safetensors, rpds-py, rfc3986-validator, rfc3339-validator, regex, pyyaml, python-json-logger, pyparsing, pycparser, pyarrow, protobuf, propcache, prometheus-client, pillow, pandocfilters, overrides, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, multidict, mistune, MarkupSafe, markdown, kiwisolver, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, joblib, idna, h11, grpcio, fsspec, frozenlist, fqdn, fonttools, filelock, dill, defusedxml, cycler, charset-normalizer, certifi, bleach, babel, attrs, async-lru, aiohappyeyeballs, absl-py, yarl, werkzeug, triton, scipy, requests, referencing, plotly, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, jupyter-server-terminals, jinja2, httpcore, deprecated, contourpy, cffi, beautifulsoup4, arrow, anyio, aiosignal, tensorboard, scikit-learn, nvidia-cusolver-cu12, matplotlib, jsonschema-specifications, isoduration, ipywidgets, huggingface-hub, httpx, argon2-cffi-bindings, aiohttp, torch, tokenizers, jupyter-console, jsonschema, argon2-cffi, transformers, nbformat, datasets, accelerate, nbclient, jupyter-events, tsfm_public, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed MarkupSafe-3.0.2 absl-py-2.1.0 accelerate-1.2.0 aiohappyeyeballs-2.4.4 aiohttp-3.11.10 aiosignal-1.3.1 anyio-4.7.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-24.2.0 babel-2.16.0 beautifulsoup4-4.12.3 bleach-6.2.0 certifi-2024.8.30 cffi-1.17.1 charset-normalizer-3.4.0 contourpy-1.3.1 cycler-0.12.1 datasets-3.1.0 defusedxml-0.7.1 deprecated-1.2.15 dill-0.3.8 fastjsonschema-2.21.1 filelock-3.16.1 fonttools-4.55.2 fqdn-1.5.1 frozenlist-1.5.0 fsspec-2024.9.0 grpcio-1.68.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 huggingface-hub-0.26.5 idna-3.10 ipywidgets-8.1.5 isoduration-20.11.0 jinja2-3.1.4 joblib-1.4.2 json5-0.10.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.3.2 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-3.0.13 kaleido-0.2.1 kiwisolver-1.4.7 markdown-3.7 matplotlib-3.9.3 mistune-3.0.2 mpmath-1.3.0 multidict-6.1.0 multiprocess-0.70.16 nbclient-0.10.1 nbconvert-7.16.4 nbformat-5.10.4 networkx-3.4.2 notebook-7.3.1 notebook-shim-0.2.4 numpy-1.26.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 overrides-7.7.0 pandas-2.2.3 pandocfilters-1.5.1 pillow-11.0.0 plotly-5.24.1 prometheus-client-0.21.1 propcache-0.2.1 protobuf-5.29.1 pyarrow-18.1.0 pycparser-2.22 pyparsing-3.2.0 python-json-logger-2.0.7 pytz-2024.2 pyyaml-6.0.2 referencing-0.35.1 regex-2024.11.6 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.22.3 safetensors-0.4.5 scikit-learn-1.5.2 scipy-1.14.1 send2trash-1.8.3 setuptools-75.6.0 sniffio-1.3.1 soupsieve-2.6 sympy-1.13.1 tenacity-9.0.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 terminado-0.18.1 threadpoolctl-3.5.0 tinycss2-1.4.0 tokenizers-0.21.0 torch-2.5.1 tqdm-4.67.1 transformers-4.47.0 triton-3.1.0 tsfm_public-0.2.18.dev9+g98730fd.d20241209 types-python-dateutil-2.9.0.20241206 typing-extensions-4.12.2 tzdata-2024.2 uri-template-1.3.0 urllib3-1.26.20 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 werkzeug-3.1.3 widgetsnbextension-4.0.13 wrapt-1.17.0 xxhash-3.5.0 yarl-1.18.3

# %% [markdown]
# ## Imports

# %%
import math
import os
import tempfile

import pandas as pd
from torch.optim import AdamW
from torch.optim.lr_scheduler import OneCycleLR
from transformers import EarlyStoppingCallback, Trainer, TrainingArguments, set_seed

from tsfm_public import (
    TimeSeriesPreprocessor,
    TrackingCallback,
    count_parameters,
    get_datasets,
)
from tsfm_public.toolkit.get_model import get_model
from tsfm_public.toolkit.lr_finder import optimal_lr_finder
from tsfm_public.toolkit.visualization import plot_predictions
# Out:
# INFO:p-4514:t-140190869663872:font_manager.py:_load_fontmanager:generated new fontManager

# %% [markdown]
# ## Important arguments

# %%
# Set seed for reproducibility
SEED = 42
set_seed(SEED)

# DATA ROOT PATH
# Make sure to download the target data (here ettm2) on the `DATA_ROOT_PATH` folder.
# ETT is available at: https://github.com/zhouhaoyi/ETDataset/tree/main
target_dataset = "venice"
DATA_ROOT_PATH = "/datasets/venice_small.csv"

# Results dir
OUT_DIR = "ttm_finetuned_models/"

# TTM model branch
TTM_MODEL_PATH = "ibm-granite/granite-timeseries-ttm-r2"

# Forecasting parameters
context_length = 1024
forecast_length = 96

# %% [markdown]
# ## Data processing pipeline

# %%
# Load the data file and see the columns

timestamp_column = "DATE"
# timestamp_column = "timestamp"
id_columns = []


data = pd.read_csv(
    DATA_ROOT_PATH,
    parse_dates=[timestamp_column],
)

"""
data[timestamp_column] = pd.to_datetime(data[timestamp_column])

# Reset the index to ensure the hours are correctly assigned, as hour information is missing in the original timestamp of this df
data[timestamp_column] = data[timestamp_column] + pd.to_timedelta(
    data.groupby(data[timestamp_column].dt.date).cumcount(), unit="h"
)
"""

print(data)
# data = pd.read_csv(
#     "/dccstor/tsfm23/datasets/exogs_expts/bike_sharing_dataset/processed_data/bike_sharing_hourly_processed.csv",
#     # parse_dates=[timestamp_column],
# )

# print(data)

# exog: Mention Exog channels in control_columns and target in target_columns

column_specifiers = {
    "timestamp_column": timestamp_column,
    "id_columns": id_columns,
    "target_columns": ["LEVEL"],
    "control_columns": [
        "PRESS",
        "RAIN",
        "TEMP",
        "WDIR",
        "WSPEED"
    ],
}

split_params = {"train": [0, 0.5], "valid": [0.5, 0.75], "test": [0.75, 1.0]}
# Out:
#        Unnamed: 0                DATE  LEVEL   PRESS  RAIN  TEMP   WDIR  \
# 0               0 2020-01-01 00:00:00   28.0  1030.8   0.0   6.6  308.0
# 1               1 2020-01-01 01:00:00   37.0  1031.3   0.0   7.0  341.0
# 2               2 2020-01-01 02:00:00   42.0  1031.2   0.0   6.8  343.0
# 3               3 2020-01-01 03:00:00   44.0  1031.1   0.0   6.9  326.0
# 4               4 2020-01-01 04:00:00   43.0  1031.1   0.0   6.9  346.0
# ...           ...                 ...    ...     ...   ...   ...    ...
# 15273       15273 2021-09-28 09:00:00    NaN  1019.6   0.0  18.8  310.0
# 15274       15274 2021-09-28 10:00:00    NaN  1019.7   0.0  20.6  328.0
# 15275       15275 2021-09-28 11:00:00    NaN  1019.6   0.0  20.5  307.0
# 15276       15276 2021-09-28 12:00:00    NaN  1019.5   0.0  21.3  270.0
# 15277       15277 2021-09-28 13:00:00    NaN  1019.1   0.0  22.6  252.0
#
#        WSPEED
# 0         3.2
# 1         3.9
# 2         2.8
# 3         2.4
# 4         4.1
# ...       ...
# 15273     2.1
# 15274     0.9
# 15275     1.2
# 15276     1.4
# 15277     1.2
#
# [15278 rows x 8 columns]

# %%
# Load the data file and see the columns

timestamp_column = "DATE"
# timestamp_column = "timestamp"
id_columns = []


data = pd.read_csv(
    DATA_ROOT_PATH,
    parse_dates=[timestamp_column],
)

"""
data[timestamp_column] = pd.to_datetime(data[timestamp_column])

# Reset the index to ensure the hours are correctly assigned, as hour information is missing in the original timestamp of this df
data[timestamp_column] = data[timestamp_column] + pd.to_timedelta(
    data.groupby(data[timestamp_column].dt.date).cumcount(), unit="h"
)
"""

print(data)
# data = pd.read_csv(
#     "/dccstor/tsfm23/datasets/exogs_expts/bike_sharing_dataset/processed_data/bike_sharing_hourly_processed.csv",
#     # parse_dates=[timestamp_column],
# )

# print(data)

# exog: Mention Exog channels in control_columns and target in target_columns

column_specifiers = {
    "timestamp_column": timestamp_column,
    "id_columns": id_columns,
    "target_columns": ["LEVEL",
        "PRESS",
        "RAIN",
        "TEMP",
        "WDIR",
        "WSPEED"],
    "control_columns": [],
}

split_params = {"train": [0, 0.5], "valid": [0.5, 0.75], "test": [0.75, 1.0]}
# Out:
#        Unnamed: 0                DATE  LEVEL   PRESS  RAIN  TEMP   WDIR  \
# 0               0 2020-01-01 00:00:00   28.0  1030.8   0.0   6.6  308.0
# 1               1 2020-01-01 01:00:00   37.0  1031.3   0.0   7.0  341.0
# 2               2 2020-01-01 02:00:00   42.0  1031.2   0.0   6.8  343.0
# 3               3 2020-01-01 03:00:00   44.0  1031.1   0.0   6.9  326.0
# 4               4 2020-01-01 04:00:00   43.0  1031.1   0.0   6.9  346.0
# ...           ...                 ...    ...     ...   ...   ...    ...
# 15273       15273 2021-09-28 09:00:00    NaN  1019.6   0.0  18.8  310.0
# 15274       15274 2021-09-28 10:00:00    NaN  1019.7   0.0  20.6  328.0
# 15275       15275 2021-09-28 11:00:00    NaN  1019.6   0.0  20.5  307.0
# 15276       15276 2021-09-28 12:00:00    NaN  1019.5   0.0  21.3  270.0
# 15277       15277 2021-09-28 13:00:00    NaN  1019.1   0.0  22.6  252.0
#
#        WSPEED
# 0         3.2
# 1         3.9
# 2         2.8
# 3         2.4
# 4         4.1
# ...       ...
# 15273     2.1
# 15274     0.9
# 15275     1.2
# 15276     1.4
# 15277     1.2
#
# [15278 rows x 8 columns]

# %%
tsp = TimeSeriesPreprocessor(
    **column_specifiers,
    context_length=context_length,
    prediction_length=forecast_length,
    scaling=True,
    encode_categorical=False,
    scaler_type="standard",
)

train_dataset, valid_dataset, test_dataset = get_datasets(
    tsp,
    data,
    split_params,
)

# %%
train_dataset[3]
# Out:
# {'past_values': tensor([[ 0.4500,  1.7846, -0.0598, -1.4340,  1.7161, -0.6739],
#          [ 0.4137,  1.7846, -0.0598, -1.4340,  1.9078, -0.1531],
#          [ 0.1960,  1.7971, -0.0598, -1.4778,  1.9462, -0.2757],
#          ...,
#          [-1.2554,  0.1096, -0.0598, -0.9374,  0.5272, -0.7964],
#          [-1.8360,  0.1096, -0.0598, -0.8497,  0.4218, -0.9802],
#          [-2.1626,  0.1596, -0.0598, -0.8205,  1.0641, -0.9496]]),
#  'future_values': tensor([[-2.0537e+00,  2.4711e-01, -5.9792e-02, -9.8120e-01, -3.2606e-01,
#           -7.6581e-01],
#          [-1.4731e+00,  2.8461e-01, -5.9792e-02, -9.6660e-01, -3.6441e-01,
#           -5.5137e-01],
#          [-8.5629e-01,  3.3461e-01, -5.9792e-02, -1.0104e+00, -9.5964e-02,
#           -5.8201e-01],
#          [-5.8014e-02,  4.4711e-01, -5.9792e-02, -9.3738e-01,  1.9085e-02,
#           -5.2074e-01],
#          [ 6.3141e-01,  4.9711e-01, -5.9792e-02, -1.0542e+00,  2.5877e-01,
#           -3.3694e-01],
#          [ 1.0668e+00,  4.9711e-01, -5.9792e-02, -9.6660e-01, -1.9264e-02,
#           -6.1246e-02],
#          [ 1.2483e+00,  5.2211e-01, -5.9792e-02, -9.8120e-01, -1.0259e+00,
#           -3.6758e-01],
#          [ 1.0305e+00,  5.5960e-01, -5.9792e-02, -1.2879e+00, -6.3286e-01,
#            2.0137e-05],
#          [ 7.4026e-01,  5.4710e-01, -5.9792e-02, -1.3756e+00, -6.6162e-01,
#           -1.8378e-01],
#          [ 8.7128e-02,  0.0000e+00,  0.0000e+00, -2.2812e+00,  0.0000e+00,
#            0.0000e+00],
#          [-4.9344e-01,  6.2210e-01, -5.9792e-02, -1.4048e+00, -8.6296e-01,
#            3.0653e-02],
#          [-8.9258e-01,  6.2210e-01, -5.9792e-02, -1.4486e+00, -7.4791e-01,
#            6.1286e-02],
#          [-1.0377e+00,  5.8460e-01, -5.9792e-02, -1.4340e+00, -6.3286e-01,
#           -3.9821e-01],
#          [-8.9258e-01,  6.4710e-01, -5.9792e-02, -1.4340e+00, -8.5337e-01,
#           -2.1441e-01],
#          [-5.2972e-01,  6.7210e-01, -5.9792e-02, -1.3902e+00, -7.5750e-01,
#           -5.2074e-01],
#          [ 5.0842e-02,  6.0960e-01, -5.9792e-02, -1.3172e+00, -1.2465e+00,
#           -2.1441e-01],
#          [ 4.8627e-01,  6.2210e-01, -5.9792e-02, -1.3464e+00, -1.3136e+00,
#            3.3698e-01],
#          [ 7.4026e-01,  5.7210e-01, -5.9792e-02, -1.3610e+00, -1.1506e+00,
#            3.9825e-01],
#          [ 6.3141e-01,  4.8461e-01, -5.9792e-02, -1.4048e+00, -1.2848e+00,
#            3.0635e-01],
#          [ 2.6855e-01,  3.7211e-01, -5.9792e-02, -1.3318e+00,  1.4860e+00,
#           -7.9644e-01],
#          [-1.6687e-01,  2.5961e-01, -5.9792e-02, -1.1711e+00,  1.1216e+00,
#           -4.9011e-01],
#          [-7.4744e-01,  2.0962e-01, -5.9792e-02, -1.2879e+00,  7.7649e-01,
#            1.8382e-01],
#          [-1.2554e+00,  1.5962e-01, -5.9792e-02, -1.2003e+00,  6.6144e-01,
#           -8.2707e-01],
#          [-1.4006e+00,  5.9621e-02, -5.9792e-02, -1.1127e+00,  4.6970e-01,
#           -7.3517e-01],
#          [-1.3280e+00,  8.4620e-02, -5.9792e-02, -1.1127e+00,  1.4284e+00,
#           -9.1897e-01],
#          [-9.6515e-01, -1.5377e-02, -5.9792e-02, -1.1127e+00,  1.2455e-01,
#           -3.6758e-01],
#          [-4.5715e-01, -5.2875e-02, -5.9792e-02, -1.0981e+00,  1.0537e-01,
#           -8.5770e-01],
#          [ 2.3227e-01, -1.9037e-01, -5.9792e-02, -1.0981e+00, -1.3999e+00,
#           -9.8024e-01],
#          [ 1.0305e+00, -2.9037e-01, -5.9792e-02, -1.0542e+00, -1.0164e+00,
#           -4.9011e-01],
#          [ 1.5023e+00, -3.9036e-01, -5.9792e-02, -1.0981e+00, -1.3232e+00,
#            4.2888e-01],
#          [ 1.7563e+00, -5.5286e-01, -5.9792e-02, -1.1419e+00, -1.1985e+00,
#            1.1641e+00],
#          [ 1.6837e+00, -3.9036e-01,  2.3869e+00, -1.3318e+00,  1.8982e+00,
#            1.9605e+00],
#          [ 1.4297e+00, -5.4036e-01, -5.9792e-02, -1.2879e+00, -1.1410e+00,
#            4.5952e-01],
#          [ 6.6769e-01, -4.4036e-01, -5.9792e-02, -1.2441e+00,  1.8503e+00,
#            1.8382e-01],
#          [ 5.0842e-02, -4.1536e-01, -5.9792e-02, -1.3610e+00,  1.5818e+00,
#           -9.1879e-02],
#          [-5.6601e-01, -3.5287e-01, -5.9792e-02, -1.3025e+00,  1.3517e+00,
#           -2.4504e-01],
#          [-6.3858e-01, -2.6537e-01, -5.9792e-02, -1.4048e+00,  1.1408e+00,
#            7.0458e-01],
#          [-1.0014e+00, -1.4037e-01, -5.9792e-02, -1.3756e+00,  9.5866e-01,
#            9.1901e-01],
#          [-8.2001e-01, -6.5375e-02, -5.9792e-02, -1.3756e+00,  1.1408e+00,
#            4.9015e-01],
#          [-5.2972e-01,  4.7121e-02, -5.9792e-02, -1.2587e+00,  1.6969e+00,
#            3.0653e-02],
#          [-4.5715e-01,  1.3462e-01, -5.9792e-02, -1.1857e+00,  1.9366e+00,
#           -1.1640e+00],
#          [-2.0316e-01,  2.3462e-01, -5.9792e-02, -9.9581e-01,  2.2042e-01,
#           -1.1947e+00],
#          [-2.3944e-01,  2.8461e-01, -5.9792e-02, -1.0834e+00,  5.7516e-01,
#           -8.2707e-01],
#          [-4.5715e-01,  2.7211e-01, -5.9792e-02, -9.6660e-01,  8.2443e-01,
#           -1.1334e+00],
#          [-7.8372e-01,  3.7211e-01, -5.9792e-02, -9.5199e-01,  2.4918e-01,
#           -9.1897e-01],
#          [-1.1466e+00,  3.8461e-01, -5.9792e-02, -8.7896e-01,  6.9979e-01,
#           -7.0454e-01],
#          [-1.4006e+00,  4.5961e-01, -5.9792e-02, -8.7896e-01,  1.6290e-01,
#           -7.0454e-01],
#          [-1.5820e+00,  5.4710e-01, -5.9792e-02, -8.4975e-01,  3.8260e-02,
#           -1.2251e-01],
#          [-1.5094e+00,  6.2210e-01, -5.9792e-02, -6.3065e-01,  2.8753e-01,
#           -1.5314e-01],
#          [-1.5820e+00,  7.4710e-01, -5.9792e-02, -7.6211e-01,  2.3001e-01,
#           -5.8201e-01],
#          [-1.3643e+00,  8.7209e-01, -5.9792e-02, -9.0817e-01, -5.4657e-01,
#           -9.1879e-02],
#          [-7.4744e-01,  9.8459e-01, -5.9792e-02, -9.3738e-01, -4.4111e-01,
#           -4.9011e-01],
#          [-2.1728e-02,  1.0596e+00, -5.9792e-02, -8.9356e-01, -7.8626e-01,
#           -2.7568e-01],
#          [ 3.7741e-01,  1.1096e+00, -5.9792e-02, -8.3514e-01, -4.0276e-01,
#           -7.9644e-01],
#          [ 9.9426e-01,  1.1596e+00, -5.9792e-02, -1.0104e+00, -5.7534e-01,
#           -2.1441e-01],
#          [ 1.1031e+00,  1.2096e+00, -5.9792e-02, -1.0396e+00, -7.4791e-01,
#            2.4508e-01],
#          [ 9.9426e-01,  1.2471e+00, -5.9792e-02, -9.6660e-01, -9.3007e-01,
#           -3.6758e-01],
#          [ 8.4912e-01,  1.2721e+00, -5.9792e-02, -1.2003e+00,  1.8886e+00,
#           -2.7568e-01],
#          [ 4.4998e-01,  1.3221e+00, -5.9792e-02, -1.3610e+00, -1.3999e+00,
#           -6.1246e-02],
#          [-5.8014e-02,  1.3846e+00, -5.9792e-02, -1.3610e+00, -1.2944e+00,
#            3.0653e-02],
#          [-6.7486e-01,  1.3971e+00, -5.9792e-02, -1.3025e+00, -1.1410e+00,
#            9.1919e-02],
#          [-1.0377e+00,  1.4721e+00, -5.9792e-02, -1.1273e+00, -1.0931e+00,
#            1.5319e-01],
#          [-1.1103e+00,  1.5471e+00, -5.9792e-02, -1.0981e+00, -1.1218e+00,
#            6.1286e-02],
#          [-1.2554e+00,  1.5846e+00, -5.9792e-02, -1.0834e+00, -1.1506e+00,
#           -1.2251e-01],
#          [-1.2554e+00,  1.6096e+00, -5.9792e-02, -1.0688e+00, -9.7801e-01,
#           -2.4504e-01],
#          [-1.1103e+00,  1.6096e+00, -5.9792e-02, -1.0396e+00, -9.3966e-01,
#           -3.3694e-01],
#          [-1.0740e+00,  1.5096e+00, -5.9792e-02, -1.0104e+00, -8.3420e-01,
#           -2.4504e-01],
#          [-1.0377e+00,  1.4471e+00, -5.9792e-02, -8.4975e-01, -6.5204e-01,
#           -2.7568e-01],
#          [-1.0014e+00,  1.4096e+00, -5.9792e-02, -7.9132e-01, -4.7946e-01,
#           -3.6758e-01],
#          [-1.0740e+00,  1.4346e+00, -5.9792e-02, -8.7896e-01, -4.5070e-01,
#           -6.1264e-01],
#          [-1.0740e+00,  1.4221e+00, -5.9792e-02, -7.9132e-01, -4.4111e-01,
#           -4.9011e-01],
#          [-1.1466e+00,  1.4096e+00, -5.9792e-02, -8.6435e-01, -2.7813e-01,
#           -2.4504e-01],
#          [-1.1103e+00,  1.4471e+00, -5.9792e-02, -8.3514e-01, -2.2060e-01,
#           -3.6758e-01],
#          [-9.2886e-01,  1.4971e+00, -5.9792e-02, -8.7896e-01, -5.3699e-01,
#           -1.0721e+00],
#          [-6.3858e-01,  1.4846e+00, -5.9792e-02, -8.7896e-01, -4.6987e-01,
#           -8.8834e-01],
#          [-3.8458e-01,  1.5721e+00, -5.9792e-02, -9.3738e-01,  1.5627e+00,
#           -1.2866e+00],
#          [-2.1728e-02,  1.4971e+00, -5.9792e-02, -9.0817e-01,  2.2042e-01,
#           -1.1947e+00],
#          [ 4.1370e-01,  1.4971e+00, -5.9792e-02, -9.2278e-01, -1.0739e+00,
#           -7.9644e-01],
#          [ 7.4026e-01,  1.4721e+00, -5.9792e-02, -1.0688e+00, -1.0643e+00,
#           -6.1264e-01],
#          [ 9.9426e-01,  1.4721e+00, -5.9792e-02, -1.0834e+00, -8.2461e-01,
#           -6.7391e-01],
#          [ 1.0668e+00,  1.4471e+00, -5.9792e-02, -1.0981e+00, -7.5750e-01,
#           -6.1264e-01],
#          [ 8.8541e-01,  1.4971e+00, -5.9792e-02, -1.0542e+00, -5.3699e-01,
#           -6.4327e-01],
#          [ 5.9512e-01,  1.4971e+00, -5.9792e-02, -9.8120e-01, -3.3565e-01,
#           -5.5137e-01],
#          [ 1.5970e-01,  1.4846e+00, -5.9792e-02, -1.0104e+00, -5.5616e-01,
#           -6.4327e-01],
#          [-3.4830e-01,  1.5471e+00, -5.9792e-02, -1.0104e+00, -6.1369e-01,
#           -6.1264e-01],
#          [-7.4744e-01,  1.6096e+00, -5.9792e-02, -1.2733e+00, -1.2465e+00,
#           -1.8378e-01],
#          [-1.1466e+00,  1.6721e+00, -5.9792e-02, -1.2295e+00, -1.2944e+00,
#           -1.8378e-01],
#          [-1.3280e+00,  1.6971e+00, -5.9792e-02, -1.2879e+00, -1.3423e+00,
#           -2.1441e-01],
#          [-1.4369e+00,  1.7346e+00, -5.9792e-02, -1.2149e+00, -1.1698e+00,
#           -1.5314e-01],
#          [-1.3280e+00,  1.6471e+00, -5.9792e-02, -1.1711e+00, -9.3007e-01,
#           -1.5314e-01],
#          [-1.3280e+00,  1.6346e+00, -5.9792e-02, -1.0981e+00, -1.1410e+00,
#            2.0137e-05],
#          [-1.1829e+00,  1.5721e+00, -5.9792e-02, -1.0834e+00, -1.0547e+00,
#            6.1286e-02],
#          [-1.0740e+00,  1.5596e+00, -5.9792e-02, -9.5199e-01, -9.3007e-01,
#           -1.8378e-01],
#          [-8.5629e-01,  1.5346e+00, -5.9792e-02, -1.1419e+00, -3.6441e-01,
#           -8.2707e-01],
#          [-7.8372e-01,  1.5346e+00, -5.9792e-02, -1.2587e+00, -3.7400e-01,
#           -6.7391e-01],
#          [-6.0229e-01,  1.5346e+00, -5.9792e-02, -1.3318e+00, -3.3565e-01,
#           -6.1264e-01]]),
#  'past_observed_mask': tensor([[True, True, True, True, True, True],
#          [True, True, True, True, True, True],
#          [True, True, True, True, True, True],
#          ...,
#          [True, True, True, True, True, True],
#          [True, True, True, True, True, True],
#          [True, True, True, True, True, True]]),
#  'future_observed_mask': tensor([[ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True, False, False,  True, False, False],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True],
#          [ True,  True,  True,  True,  True,  True]]),
#  'timestamp': Timestamp('2020-02-12 18:00:00'),
#  'id': (0,)}

# %% [markdown]
# ## Zero-shot evaluation method

# %%
zeroshot_model = get_model(
    TTM_MODEL_PATH,
    context_length=context_length,
    prediction_length=forecast_length,
    prediction_channel_indices=tsp.prediction_channel_indices,
    num_input_channels=tsp.num_input_channels,
)

zeroshot_model
# Out:
# INFO:p-4514:t-140190869663872:get_model.py:get_model:Loading model from: ibm-granite/granite-timeseries-ttm-r2
# INFO:p-4514:t-140190869663872:get_model.py:get_model:Selected TTM `prediction_length` = 96
# INFO:p-4514:t-140190869663872:get_model.py:get_model:Model loaded successfully!
# INFO:p-4514:t-140190869663872:get_model.py:get_model:[TTM] context_len = 1024, forecast_len = 96
# TinyTimeMixerForPrediction(
#   (backbone): TinyTimeMixerModel(
#     (encoder): TinyTimeMixerEncoder(
#       (patcher): Linear(in_features=128, out_features=384, bias=True)
#       (mlp_mixer_encoder): TinyTimeMixerBlock(
#         (mixers): ModuleList(
#           (0): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=32, out_features=64, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=64, out_features=32, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=32, out_features=32, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=96, out_features=192, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=192, out_features=96, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=96, out_features=96, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (1): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=16, out_features=32, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=32, out_features=16, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=16, out_features=16, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=192, out_features=384, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=384, out_features=192, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=192, out_features=192, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (2): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=8, out_features=16, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=16, out_features=8, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=384, out_features=768, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=768, out_features=384, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=384, out_features=384, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (patching): TinyTimeMixerPatchify()
#     (scaler): TinyTimeMixerStdScaler()
#   )
#   (decoder): TinyTimeMixerDecoder(
#     (adapter): Linear(in_features=384, out_features=256, bias=True)
#     (decoder_block): TinyTimeMixerBlock(
#       (mixers): ModuleList(
#         (0-1): 2 x TinyTimeMixerLayer(
#           (patch_mixer): PatchMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=8, out_features=16, bias=True)
#               (dropout1): Dropout(p=0.4, inplace=False)
#               (fc2): Linear(in_features=16, out_features=8, bias=True)
#               (dropout2): Dropout(p=0.4, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#           (feature_mixer): FeatureMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=256, out_features=512, bias=True)
#               (dropout1): Dropout(p=0.4, inplace=False)
#               (fc2): Linear(in_features=512, out_features=256, bias=True)
#               (dropout2): Dropout(p=0.4, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=256, out_features=256, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#         )
#       )
#     )
#   )
#   (head): TinyTimeMixerForPredictionHead(
#     (dropout_layer): Dropout(p=0.4, inplace=False)
#     (base_forecast_block): Linear(in_features=2048, out_features=96, bias=True)
#     (flatten): Flatten(start_dim=-2, end_dim=-1)
#   )
# )

# %%
temp_dir = tempfile.mkdtemp()
# zeroshot_trainer
zeroshot_trainer = Trainer(
    model=zeroshot_model,
    args=TrainingArguments(
        output_dir=temp_dir,
        per_device_eval_batch_size=64,
    ),
)

# %%
zeroshot_trainer.evaluate(test_dataset)
# Out:
#     <div>
#
#       <progress value='59' max='59' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [59/59 00:01]
#     </div>
# {'eval_loss': 0.4612501263618469,
#  'eval_model_preparation_time': 0.0019,
#  'eval_runtime': 1.2482,
#  'eval_samples_per_second': 2984.276,
#  'eval_steps_per_second': 47.268}

# %%
# plot
plot_predictions(
    model=zeroshot_trainer.model,
    dset=test_dataset,
    plot_dir=os.path.join(OUT_DIR, "bike_sharing"),
    plot_prefix="test_zeroshot",
    channel=0,
)

# %% [markdown]
#  ## Few-shot finetune and evaluation method

# %% [markdown]
# ### Load model
# Optionally, we can change some parameters of the model, e.g., dropout of the head.

# %%
finetune_forecast_model = get_model(
    TTM_MODEL_PATH,
    context_length=context_length,
    prediction_length=forecast_length,
    num_input_channels=tsp.num_input_channels,
    decoder_mode="mix_channel",  # exog:  set to mix_channel for mixing channels in history
    prediction_channel_indices=tsp.prediction_channel_indices,
    exogenous_channel_indices=tsp.exogenous_channel_indices,
    fcm_context_length=1,  # exog: indicates lag length to use in the exog fusion. for Ex. if today sales can get affected by discount on +/- 2 days, mention 2
    fcm_use_mixer=True,  # exog: Try true (1st option) or false
    fcm_mix_layers=2,  # exog: Number of layers for exog mixing
    enable_forecast_channel_mixing=True,  # exog: set true for exog mixing
    fcm_prepend_past=True,  # exog: set true to include lag from history during exog infusion.
)
finetune_forecast_model
# Out:
# INFO:p-4514:t-140190869663872:get_model.py:get_model:Loading model from: ibm-granite/granite-timeseries-ttm-r2
# INFO:p-4514:t-140190869663872:get_model.py:get_model:Selected TTM `prediction_length` = 96
# Some weights of TinyTimeMixerForPrediction were not initialized from the model checkpoint at ibm-granite/granite-timeseries-ttm-r2 and are newly initialized: ['decoder.decoder_block.mixers.0.channel_feature_mixer.gating_block.attn_layer.bias', 'decoder.decoder_block.mixers.0.channel_feature_mixer.gating_block.attn_layer.weight', 'decoder.decoder_block.mixers.0.channel_feature_mixer.mlp.fc1.bias', 'decoder.decoder_block.mixers.0.channel_feature_mixer.mlp.fc1.weight', 'decoder.decoder_block.mixers.0.channel_feature_mixer.mlp.fc2.bias', 'decoder.decoder_block.mixers.0.channel_feature_mixer.mlp.fc2.weight', 'decoder.decoder_block.mixers.0.channel_feature_mixer.norm.norm.bias', 'decoder.decoder_block.mixers.0.channel_feature_mixer.norm.norm.weight', 'decoder.decoder_block.mixers.1.channel_feature_mixer.gating_block.attn_layer.bias', 'decoder.decoder_block.mixers.1.channel_feature_mixer.gating_block.attn_layer.weight', 'decoder.decoder_block.mixers.1.channel_feature_mixer.mlp.fc1.bias', 'decoder.decoder_block.mixers.1.channel_feature_mixer.mlp.fc1.weight', 'decoder.decoder_block.mixers.1.channel_feature_mixer.mlp.fc2.bias', 'decoder.decoder_block.mixers.1.channel_feature_mixer.mlp.fc2.weight', 'decoder.decoder_block.mixers.1.channel_feature_mixer.norm.norm.bias', 'decoder.decoder_block.mixers.1.channel_feature_mixer.norm.norm.weight', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.gating_block.attn_layer.bias', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.gating_block.attn_layer.weight', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.mlp.fc1.bias', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.mlp.fc1.weight', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.mlp.fc2.bias', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.mlp.fc2.weight', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.norm.norm.bias', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.norm.norm.weight', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.gating_block.attn_layer.bias', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.gating_block.attn_layer.weight', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.mlp.fc1.bias', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.mlp.fc1.weight', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.mlp.fc2.bias', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.mlp.fc2.weight', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.norm.norm.bias', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.norm.norm.weight', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.gating_block.attn_layer.bias', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.gating_block.attn_layer.weight', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.mlp.fc1.bias', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.mlp.fc1.weight', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.mlp.fc2.bias', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.mlp.fc2.weight', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.norm.norm.bias', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.norm.norm.weight', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.gating_block.attn_layer.bias', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.gating_block.attn_layer.weight', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.mlp.fc1.bias', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.mlp.fc1.weight', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.mlp.fc2.bias', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.mlp.fc2.weight', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.norm.norm.bias', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.norm.norm.weight', 'head.fcm_block.fcm_embedding.bias', 'head.fcm_block.fcm_embedding.weight', 'head.fcm_block.fcm_gating_block.attn_layer.bias', 'head.fcm_block.fcm_gating_block.attn_layer.weight', 'head.fcm_block.mlp.bias', 'head.fcm_block.mlp.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:p-4514:t-140190869663872:get_model.py:get_model:Model loaded successfully!
# INFO:p-4514:t-140190869663872:get_model.py:get_model:[TTM] context_len = 1024, forecast_len = 96
# TinyTimeMixerForPrediction(
#   (backbone): TinyTimeMixerModel(
#     (encoder): TinyTimeMixerEncoder(
#       (patcher): Linear(in_features=128, out_features=384, bias=True)
#       (mlp_mixer_encoder): TinyTimeMixerBlock(
#         (mixers): ModuleList(
#           (0): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=32, out_features=64, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=64, out_features=32, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=32, out_features=32, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=96, out_features=192, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=192, out_features=96, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=96, out_features=96, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (1): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=16, out_features=32, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=32, out_features=16, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=16, out_features=16, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=192, out_features=384, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=384, out_features=192, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=192, out_features=192, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (2): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=8, out_features=16, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=16, out_features=8, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=384, out_features=768, bias=True)
#                     (dropout1): Dropout(p=0.4, inplace=False)
#                     (fc2): Linear(in_features=768, out_features=384, bias=True)
#                     (dropout2): Dropout(p=0.4, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=384, out_features=384, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (patching): TinyTimeMixerPatchify()
#     (scaler): TinyTimeMixerStdScaler()
#   )
#   (decoder): TinyTimeMixerDecoder(
#     (adapter): Linear(in_features=384, out_features=256, bias=True)
#     (decoder_block): TinyTimeMixerBlock(
#       (mixers): ModuleList(
#         (0-1): 2 x TinyTimeMixerLayer(
#           (patch_mixer): PatchMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=8, out_features=16, bias=True)
#               (dropout1): Dropout(p=0.4, inplace=False)
#               (fc2): Linear(in_features=16, out_features=8, bias=True)
#               (dropout2): Dropout(p=0.4, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#           (feature_mixer): FeatureMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=256, out_features=512, bias=True)
#               (dropout1): Dropout(p=0.4, inplace=False)
#               (fc2): Linear(in_features=512, out_features=256, bias=True)
#               (dropout2): Dropout(p=0.4, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=256, out_features=256, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#           (channel_feature_mixer): TinyTimeMixerChannelFeatureMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=6, out_features=12, bias=True)
#               (dropout1): Dropout(p=0.4, inplace=False)
#               (fc2): Linear(in_features=12, out_features=6, bias=True)
#               (dropout2): Dropout(p=0.4, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=6, out_features=6, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#         )
#       )
#     )
#   )
#   (head): TinyTimeMixerForPredictionHead(
#     (dropout_layer): Dropout(p=0.4, inplace=False)
#     (base_forecast_block): Linear(in_features=2048, out_features=96, bias=True)
#     (flatten): Flatten(start_dim=-2, end_dim=-1)
#     (fcm_block): ForecastChannelHeadMixer(
#       (exog_mixer): TinyTimeMixerBlock(
#         (mixers): ModuleList(
#           (0-1): 2 x TinyTimeMixerLayer(
#             (patch_mixer): PatchMixerBlock(
#               (norm): TinyTimeMixerNormLayer(
#                 (norm): LayerNorm((6,), eps=1e-05, elementwise_affine=True)
#               )
#               (mlp): TinyTimeMixerMLP(
#                 (fc1): Linear(in_features=6, out_features=12, bias=True)
#                 (dropout1): Dropout(p=0.4, inplace=False)
#                 (fc2): Linear(in_features=12, out_features=6, bias=True)
#                 (dropout2): Dropout(p=0.4, inplace=False)
#               )
#               (gating_block): TinyTimeMixerGatedAttention(
#                 (attn_layer): Linear(in_features=6, out_features=6, bias=True)
#                 (attn_softmax): Softmax(dim=-1)
#               )
#             )
#             (feature_mixer): FeatureMixerBlock(
#               (norm): TinyTimeMixerNormLayer(
#                 (norm): LayerNorm((6,), eps=1e-05, elementwise_affine=True)
#               )
#               (mlp): TinyTimeMixerMLP(
#                 (fc1): Linear(in_features=6, out_features=12, bias=True)
#                 (dropout1): Dropout(p=0.4, inplace=False)
#                 (fc2): Linear(in_features=12, out_features=6, bias=True)
#                 (dropout2): Dropout(p=0.4, inplace=False)
#               )
#               (gating_block): TinyTimeMixerGatedAttention(
#                 (attn_layer): Linear(in_features=6, out_features=6, bias=True)
#                 (attn_softmax): Softmax(dim=-1)
#               )
#             )
#           )
#         )
#       )
#       (fcm_embedding): Linear(in_features=3, out_features=6, bias=True)
#       (mlp): Linear(in_features=36, out_features=6, bias=True)
#       (fcm_gating_block): TinyTimeMixerGatedAttention(
#         (attn_layer): Linear(in_features=36, out_features=36, bias=True)
#         (attn_softmax): Softmax(dim=-1)
#       )
#       (fcm_patch_block): TinyTimeMixerPatchify()
#     )
#   )
# )

# %% [markdown]
# ### Frezze the TTM backbone

# %%
print(
    "Number of params before freezing backbone",
    count_parameters(finetune_forecast_model),
)

# Freeze the backbone of the model
for param in finetune_forecast_model.backbone.parameters():
    param.requires_grad = False

# Count params
print(
    "Number of params after freezing the backbone",
    count_parameters(finetune_forecast_model),
)
# Out:
# Number of params before freezing backbone 2968834
# Number of params after freezing the backbone 959298

# %% [markdown]
# ### Finetune model with decoder mixing and exog fusion

# %%
# Important parameters


# learning_rate = 0.000298364724028334
num_epochs = 50  # Ideally, we need more epochs (try offline preferably in a gpu for faster computation)
batch_size = 64

learning_rate, finetune_forecast_model = optimal_lr_finder(
    finetune_forecast_model,
    train_dataset,
    batch_size=batch_size,
    enable_prefix_tuning=False,
)
print("OPTIMAL SUGGESTED LEARNING RATE =", learning_rate)
# Out:
# INFO:p-4514:t-140190869663872:lr_finder.py:optimal_lr_finder:LR Finder: Running learning rate (LR) finder algorithm. If the suggested LR is very low, we suggest setting the LR manually.
# INFO:p-4514:t-140190869663872:lr_finder.py:optimal_lr_finder:LR Finder: Using GPU:0.
# /home/proz/Progetti/ttm_new/TTM/granite-tsfm/tsfm_public/toolkit/lr_finder.py:62: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(path, map_location=device)
# INFO:p-4514:t-140190869663872:lr_finder.py:optimal_lr_finder:LR Finder: Suggested learning rate = 0.0010974987654930567
# OPTIMAL SUGGESTED LEARNING RATE = 0.0010974987654930567

# %%
print(f"Using learning rate = {learning_rate}")
finetune_forecast_args = TrainingArguments(
    output_dir=os.path.join(OUT_DIR, "output"),
    overwrite_output_dir=True,
    learning_rate=learning_rate,
    num_train_epochs=num_epochs,
    do_eval=True,
    evaluation_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    dataloader_num_workers=8,
    report_to=None,
    save_strategy="epoch",
    logging_strategy="epoch",
    save_total_limit=1,
    logging_dir=os.path.join(OUT_DIR, "logs"),  # Make sure to specify a logging directory
    load_best_model_at_end=True,  # Load the best model when training ends
    metric_for_best_model="eval_loss",  # Metric to monitor for early stopping
    greater_is_better=False,  # For loss
)

# Create the early stopping callback
early_stopping_callback = EarlyStoppingCallback(
    early_stopping_patience=10,  # Number of epochs with no improvement after which to stop
    early_stopping_threshold=0.0,  # Minimum improvement required to consider as improvement
)
tracking_callback = TrackingCallback()

# Optimizer and scheduler
optimizer = AdamW(finetune_forecast_model.parameters(), lr=learning_rate)
scheduler = OneCycleLR(
    optimizer,
    learning_rate,
    epochs=num_epochs,
    steps_per_epoch=math.ceil(len(train_dataset) / (batch_size)),
)

finetune_forecast_trainer = Trainer(
    model=finetune_forecast_model,
    args=finetune_forecast_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
    callbacks=[early_stopping_callback, tracking_callback],
    optimizers=(optimizer, scheduler),
)

# Fine tune
finetune_forecast_trainer.train()
# Out:
# Using learning rate = 0.0010974987654930567
# /home/proz/Progetti/ttm_new/ttm-env/lib/python3.12/site-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='1530' max='5100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1530/5100 01:06 < 02:36, 22.86 it/s, Epoch 15/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.838800</td>
#       <td>0.819439</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.748800</td>
#       <td>0.799051</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.702200</td>
#       <td>0.798148</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.663700</td>
#       <td>0.796421</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.620600</td>
#       <td>0.794409</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.578300</td>
#       <td>0.795966</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.537500</td>
#       <td>0.809578</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.510400</td>
#       <td>0.823186</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.492900</td>
#       <td>0.831814</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.476500</td>
#       <td>0.831214</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.464100</td>
#       <td>0.832727</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.455400</td>
#       <td>0.849744</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.449100</td>
#       <td>0.851017</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.442500</td>
#       <td>0.847148</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.437300</td>
#       <td>0.849243</td>
#     </tr>
#   </tbody>
# </table><p>
# [TrackingCallback] Mean Epoch Time = 3.2798412799835206 seconds, Total Train Time = 67.09414958953857
# TrainOutput(global_step=1530, training_loss=0.561204626045975, metrics={'train_runtime': 67.0951, 'train_samples_per_second': 4858.775, 'train_steps_per_second': 76.012, 'total_flos': 1.07035348451328e+16, 'train_loss': 0.561204626045975, 'epoch': 15.0})

# %%
finetune_forecast_trainer.evaluate(test_dataset)
# Out:
#     <div>
#
#       <progress value='59' max='59' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [59/59 00:00]
#     </div>
# {'eval_loss': 0.39222452044487,
#  'eval_runtime': 1.336,
#  'eval_samples_per_second': 2788.122,
#  'eval_steps_per_second': 44.161,
#  'epoch': 15.0}

# %%
plot_predictions(
    model=finetune_forecast_trainer.model,
    dset=test_dataset,
    plot_dir=os.path.join(OUT_DIR, "bike_sharing"),
    plot_prefix="test_finetune",
    channel=0,
)
